# %% [markdown]
# Rather than having one X entry for each day, tune the code so that there can be one X entry for each location on each day. This will be put the data in a form that is convenient for feature engineering.

# %%
import os
os.chdir('..')

# %%
import solar.wrangle.wrangle
from solar.wrangle.wrangle import SolarData

# %%
reload(solar.wrangle.wrangle)
from solar.wrangle.wrangle import SolarData

station = ['ACME', 'BEAV']
train_dates = ['2005-07-29','2005-08-29']
test_dates = ['2008-12-29', '2009-01-29']
#var = ['dswrf_sfc', 'uswrf_sfc', 'spfh_2m', 'ulwrf_tatm']
var = ['dswrf_sfc']
models = [0]
times = [18]
lats = range(37,38)
longs = range(265,268)
X_par = {'train_dates':train_dates, 'test_dates':test_dates, 'var':var, 'models':models, 'times':times, 'lats':lats,
        'longs':longs}
y_par = {'station':station, 'train_dates':train_dates, 'lats':lats, 'longs':longs}
trainX, trainy, testX = SolarData.load('solar/data/kaggle_solar/train/', 'solar/data/kaggle_solar/train.csv', 
                                'solar/data/kaggle_solar/test', 'solar/data/kaggle_solar/station_info.csv', 
                                learn_type='one_to_location', station=station, train_dates=train_dates, 
                                test_dates=test_dates, lats=lats, longs=longs, var=var, models=models, times=times)
# Out:
# Training data shape (64, 3) (64, 1)

# %%
import solar.wrangle.engineer

# %%
reload(solar.wrangle.engineer)
from solar.wrangle.engineer import Engineer

station = ['ACME', 'BEAV']
train_dates = ['2005-07-29','2005-08-29']
test_dates = ['2008-12-29', '2009-01-29']
var = ['dswrf_sfc', 'uswrf_sfc', 'spfh_2m', 'ulwrf_tatm']
#var = ['dswrf_sfc']
models = [0,1]
times = [18,21]
lats = range(37,38)
longs = range(265,268)
X_par = {'train_dates':train_dates, 'test_dates':test_dates, 'var':var, 'models':models, 'times':times, 'lats':lats,
        'longs':longs}
y_par = {'station':station, 'train_dates':train_dates, 'lats':lats, 'longs':longs}
new_feats = {'grid'}
trainX, trainy, testX, locy = Engineer.engineer('solar/data/kaggle_solar/train/', 'solar/data/kaggle_solar/train.csv', 
                                'solar/data/kaggle_solar/test/', 'solar/data/kaggle_solar/station_info.csv',
                                X_par, y_par, new_feats)

# %%
trainX.shape
# Out:
# (64, 64)

# %%
import solar.wrangle.wrangle
import solar.wrangle.engineer

# %%
reload(solar.wrangle.wrangle)
reload(solar.wrangle.engineer)


from solar.wrangle.wrangle import SolarData
from solar.wrangle.engineer import Engineer

station = ['all']
train_dates = ['2005-07-29','2005-08-29']
test_dates = ['2008-12-29', '2009-01-29']
#var = ['dswrf_sfc', 'uswrf_sfc', 'spfh_2m', 'ulwrf_tatm']
var = ['all']
models = [0]
times = [18]
lats = range(37,38)
longs = range(265,268)
new_feats = {'grid'}
input_data = SolarData.load('solar/data/kaggle_solar/train/', 'solar/data/kaggle_solar/train.csv', 
                                'solar/data/kaggle_solar/test', 'solar/data/kaggle_solar/station_info.csv',
                                new_feats, station=station, train_dates=train_dates, 
                                test_dates=test_dates, lats=lats, longs=longs, var=var, models=models, times=times)
# Out:
# Training data shape (32, 60) (32, 98)

# %%
input_data[0]
# Out:
# variable         apcp_sfc                                               \
# model                   0
# time                   18
# lat                     N                             S
# lon                     E              W              E              W
# date
# 2005-07-29     308.784149     310.884155     310.284149     313.484161
# 2005-07-30     451.000000     492.000000     498.000000     494.000000
# 2005-07-31     410.338135     402.338135     412.338135     409.338135
# 2005-08-01      84.000000     101.000000      95.000000     100.000000
# 2005-08-02     472.117249     476.117249     478.117249     482.117249
# 2005-08-03     253.117249     262.117249     259.117249     264.117249
# 2005-08-04      50.299999      46.700001      52.700001      51.500000
# 2005-08-05       0.010000       0.020000       0.000000       0.000000
# 2005-08-06       0.000000       0.090000       0.000000       0.030000
# 2005-08-07  101109.359375  101039.359375  101178.164062  101103.562500
# 2005-08-08       0.015700       0.015110       0.016330       0.016150
# 2005-08-09       0.008000       0.018000       0.004200       0.001300
# 2005-08-10     305.300079     305.200073     306.600067     306.300079
# 2005-08-11     296.428925     295.728943     296.728943     296.928925
# 2005-08-12     305.264099     305.164093     306.464081     306.264099
# 2005-08-13     308.164062     309.864075     309.864075     311.264069
# 2005-08-14     346.000000     316.000000     249.000000     331.000000
# 2005-08-15     408.155121     401.155121     418.155121     413.155121
# 2005-08-16      63.000000      62.000000      43.000000      62.000000
# 2005-08-17     454.962036     440.962036     453.962036     464.962036
# 2005-08-18     235.981018     242.981018     215.981018     220.981018
# 2005-08-19      54.010807      51.710804      54.810806      53.710804
# 2005-08-20       0.140000       0.220000       0.140000       0.550000
# 2005-08-21       0.570000       0.530000       6.210000       9.460000
# 2005-08-22  101520.687500  101569.687500  101404.890625  101373.890625
# 2005-08-23       0.016270       0.014310       0.018040       0.017190
# 2005-08-24       0.139100       0.221100       0.139800       0.556800
# 2005-08-25     299.281281     297.481262     301.881287     301.181274
# 2005-08-26     294.011383     293.211365     296.011383     296.011383
# 2005-08-27     299.317841     297.517853     301.917847     301.117859
# 2005-08-28     301.949524     300.849518     304.649506     303.949524
# 2005-08-29     180.000000     175.000000     335.000000      60.000000
#
# variable        dlwrf_sfc                                               \
# model                   0
# time                   18
# lat                     N                             S
# lon                     E              W              E              W
# date
# 2005-07-29     112.000000     117.000000     113.000000     115.000000
# 2005-07-30     466.576996     480.576996     470.576996     483.576996
# 2005-07-31     288.576996     292.576996     294.576996     296.576996
# 2005-08-01      23.900000      23.200001      21.299999      22.900000
# 2005-08-02       0.000000       0.000000       0.000000       0.000000
# 2005-08-03       0.000000       0.000000       0.000000       0.000000
# 2005-08-04  101956.718750  101893.523438  101923.437500  101854.796875
